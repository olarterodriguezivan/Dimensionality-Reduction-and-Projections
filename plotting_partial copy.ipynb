# %% [markdown]
# # Analyzing some tendencies after slim dimensionality reduction with Random Embeddings
#
# In this script we just focus on some partial dataset wherein we use $d=20$ on just a subset of functions from BBOB (i.e. $f=\{1,8,11,16,20 \}$). What we want to do is then check how some features from the Exploratory Landscape Analysis Toolbox (i.e. FLACCO) behave under a projection with Random Embeddings with a projection matrix $P \in \mathbb{R}^{d \times q}$. In this case we set $q=10$ as a preliminary value to have $50\%$ reduction.

# %% [markdown]
# ## Procedure
# For this case, we use the package `sklearn.random_projection.GaussianRandomProjection` in order to generate the random projection matrices. This generates random matrices where $\left\|P \right\|_{2}=1.0$. With this in mind, we generate 10 different random projection matrices of this kind. Furthermore, we generated beforehand initial 10 datasets of $\mathbf{X} \in [-5,5]^{d}$ with $100 d$ samples via `LHS`. *A priori*, the sampling scheme wouldn't signify a very different performance with respect to other sampling available techniques since the Random Projection will transform any initial space-filling optimized Design of Experiments scheme into some degenerate one since there'll be artificial correlations caused by the projection into the reduced latent space.
#
# ### Sampled ELA Features
# After what was discussed in some references (i.e. *Expressiveness and Robustness of Landscape Features*, Renau et al., 2019), we sampled the following sets of ELA Features:
# - **Dispersion (disp)**
# - **Information Content (ic)**
# - **Nearest Best Clustering (nbc)**
# - **Principal Component Analysis (pca)**
# - **Meta Model (ela_meta)**
# - **$y$-distribution (ela_distr)**
# - **Level Set (ela_level)**
#
# From the set of features, it's self-evident that the **$y$-distribution** features, these are invariant to any dimensionality reduction techniques since the scope of these features is just the *objective space*. However to account for subsampling in a high dimensional space we proceed to generate subsets of $100 q$ by sampling without replacement from the initial dataset. The idea is then two-fold: 1) We simulate what would happen what happens by keeping the same *dimensionality propertion* and 2) we can study the stability and possible distributions of the features. We hypothesize that the distributions of features by performing this sampling will depend primarily on the sampled function.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# Import necessary libraries
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Define file paths
ela_features_reduced_path = Path("ela_features_reduced_3/ELA_extraction/D_20").resolve()
ela_features_complete_path = Path("ela_features_3/ELA_extraction/Dimension_20").resolve()

# %%
# Get list of CSV files in both directories
reduced_files = sorted(ela_features_reduced_path.rglob("*.csv"))
complete_files = sorted(ela_features_complete_path.rglob("*.csv"))

# %%
complete_files
# Out:
# [WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_1/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_10/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_11/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_12/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_13/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_14/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_15/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_16/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_17/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_18/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_19/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_2/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_20/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_21/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_22/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_23/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_24/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_3/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_4/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_5/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_5/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_5/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_5/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_5/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_5/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1001/Samples_200/f_5/id_14/ela_features.csv'),
# ...
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_20/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_21/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_22/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_23/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_24/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_4/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_5/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_6/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_7/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_8/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_3/id_9/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_0/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_1/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_10/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_11/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_12/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_13/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_14/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_2/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_3/ela_features.csv'),
#  WindowsPath('C:/Users/iolar/Documents/ELA-Dim_Red_study/ela_dim_red/ela_features_3/ELA_extraction/Dimension_20/seed_1003/Samples_200/f_4/id_4/ela_features.csv'),
#  ...]

# %%
def extract_meta_data_from_reduced_feature_file_path(file_path: Path) -> dict:
    """
    Extracts meta data from the reduced feature file path.
    
    Parameters:
    file_path (Path): Path object of the reduced feature file.
    
    Returns:
    dict: A dictionary containing the extracted meta data.
    """
    """
    Extract key-value numeric metadata from path segments like key_value.
    """

    if not isinstance(file_path, (str, Path)):
        raise ValueError("path must be a string or Path object")

    file_path = Path(file_path)

    if not file_path.exists():
        raise FileNotFoundError(f"The path {file_path} does not exist.")

    metadata = {}

    round_txt = file_path.parts[-1]
    round_number = int(round_txt.split("_")[-1].replace(".csv", ""))
    metadata["round"] = round_number

    embedding_seed_txt = file_path.parts[-2]
    embedding_seed = int(embedding_seed_txt.split("_")[-1])
    metadata["embedding_seed"] = embedding_seed

    reduction_ratio_txt = file_path.parts[-4]
    reduction_ratio = float(reduction_ratio_txt.split("_")[-1])
    metadata["reduction_ratio"] = reduction_ratio

    instance_idx_txt = file_path.parts[-5]
    instance_idx = int(instance_idx_txt.split("_")[-1])
    metadata["instance_idx"] = instance_idx

    function_idx_txt = file_path.parts[-6]
    function_idx = int(function_idx_txt.split("_")[-1])
    metadata["function_idx"] = function_idx

    n_samples_txt = file_path.parts[-7]
    n_samples = int(n_samples_txt.split("_")[-1])
    metadata["n_samples"] = n_samples

    seed_txt = file_path.parts[-8]
    seed = int(seed_txt.split("_")[-1])
    metadata["seed_lhs"] = seed

    dimension_txt = file_path.parts[-9]
    dimension = int(dimension_txt.split("_")[-1])
    metadata["dimension"] = dimension
    
    return metadata

# %%
def extract_meta_data_from_complete_feature_file_path(file_path: Path) -> dict:
    """
    Extracts meta data from the complete feature file path.
    
    Parameters:
    file_path (Path): Path object of the complete feature file.
    
    Returns:
    dict: A dictionary containing the extracted meta data.
    """
    """
    Extract key-value numeric metadata from path segments like key_value.
    """

    if not isinstance(file_path, (str, Path)):
        raise ValueError("path must be a string or Path object")

    file_path = Path(file_path)

    if not file_path.exists():
        raise FileNotFoundError(f"The path {file_path} does not exist.")

    metadata = {}



    instance_idx_txt = file_path.parts[-2]
    instance_idx = int(instance_idx_txt.split("_")[-1])
    metadata["instance_idx"] = instance_idx

    function_idx_txt = file_path.parts[-3]
    function_idx = int(function_idx_txt.split("_")[-1])
    metadata["function_idx"] = function_idx

    n_samples_txt = file_path.parts[-4]
    n_samples = int(n_samples_txt.split("_")[-1])
    metadata["n_samples"] = n_samples

    seed_txt = file_path.parts[-5]
    seed = int(seed_txt.split("_")[-1])
    metadata["seed_lhs"] = seed

    dimension_txt = file_path.parts[-6]
    dimension = int(dimension_txt.split("_")[-1])
    metadata["dimension"] = dimension
    
    return metadata

# %%
# Generate DataFrames by loading CSV files and combining with metadata
complete_dfs = []

for file_path in complete_files:
    df = pd.read_csv(file_path)
    # Extract metadata for the current file
    meta = extract_meta_data_from_complete_feature_file_path(file_path)
    # Add metadata as new columns to the DataFrame
    for key, value in meta.items():
        df[key] = value
    
    complete_dfs.append(df)

complete_df = (
    pd.concat(complete_dfs, ignore_index=True)
    if complete_dfs
    else pd.DataFrame()
)

# %%
complete_df
# Out:
#        ela_meta.lin_simple.adj_r2  ela_meta.lin_simple.intercept  \
# 0                        0.962144                     160.869757
# 1                        0.964638                     335.922967
# 2                        0.967974                     270.796736
# 3                        0.974033                     517.169845
# 4                        0.965981                     687.013063
# ...                           ...                            ...
# 14395                    0.144625                  370880.256463
# 14396                    0.120491                  386739.336532
# 14397                    0.104993                  391684.214659
# 14398                    0.075283                  381225.475439
# 14399                    0.084220                  379403.277033
#
#        ela_meta.lin_simple.coef.min  ela_meta.lin_simple.coef.max  \
# 0                          0.208150                      6.897319
# 1                          0.275050                      8.334917
# 2                          0.295733                      8.240517
# 3                          0.287559                      7.885662
# 4                          0.447831                      8.124321
# ...                             ...                           ...
# 14395                    739.974365                   8968.688930
# 14396                   1153.724119                   9984.493939
# 14397                    363.626773                   9695.349592
# 14398                     23.291751                  11076.243401
# 14399                    637.600190                   9666.423641
#
#        ela_meta.lin_simple.coef.max_by_min  ela_meta.lin_w_interact.adj_r2  \
# 0                                33.136309                             1.0
# 1                                30.303267                             1.0
# 2                                27.864715                             1.0
# 3                                27.422780                             1.0
# 4                                18.141469                             1.0
# ...                                    ...                             ...
# 14395                            12.120270                             1.0
# 14396                             8.654143                             1.0
# 14397                            26.662915                             1.0
# 14398                           475.543611                             1.0
# 14399                            15.160635                             1.0
#
#        ela_meta.quad_simple.adj_r2  ela_meta.quad_simple.cond  \
# 0                         1.000000                   1.000000
# 1                         1.000000                   1.000000
# 2                         1.000000                   1.000000
# 3                         1.000000                   1.000000
# 4                         1.000000                   1.000000
# ...                            ...                        ...
# 14395                     0.155769                   6.774635
# 14396                     0.210411                   3.884893
# 14397                     0.254936                   4.057301
# 14398                     0.340456                   3.501203
# 14399                     0.267714                   2.608607
#
#        ela_meta.quad_w_interact.adj_r2  ela_meta.costs_runtime  ...  \
# 0                                  1.0                   0.344  ...
# 1                                  1.0                   0.391  ...
# 2                                  1.0                   0.375  ...
# 3                                  1.0                   0.328  ...
# 4                                  1.0                   0.359  ...
# ...                                ...                     ...  ...
# 14395                              1.0                   0.265  ...
# 14396                              1.0                   0.312  ...
# 14397                              1.0                   0.265  ...
# 14398                              1.0                   0.282  ...
# 14399                              1.0                   0.282  ...
#
#        fitness_distance.distance_mean  fitness_distance.distance_std  \
# 0                           15.089905                       3.799821
# 1                           15.035332                       3.894132
# 2                           14.240422                       3.720427
# 3                           15.664009                       4.070778
# 4                           15.488229                       3.971765
# ...                               ...                            ...
# 14395                       17.547887                       4.579231
# 14396                       16.958328                       4.662510
# 14397                       17.437299                       4.526222
# 14398                       16.926827                       4.576537
# 14399                       16.552341                       4.194189
#
#        fitness_distance.fitness_mean  fitness_distance.fitness_std  \
# 0                          68.025586                     19.995332
# 1                         239.367762                     26.894356
# 2                         161.370658                     30.202780
# 3                         406.725583                     28.066969
# 4                         587.621887                     25.655925
# ...                              ...                           ...
# 14395                  199923.837446                  28547.814904
# 14396                  211203.126564                  24256.325677
# 14397                  218569.667090                  22860.200756
# 14398                  189939.097075                  38003.144007
# 14399                  198744.006092                  27034.532246
#
#        fitness_distance.costs_runtime  instance_idx  function_idx  n_samples  \
# 0                               0.000             0             1        200
# 1                               0.000             1             1        200
# 2                               0.000            10             1        200
# 3                               0.000            11             1        200
# 4                               0.000            12             1        200
# ...                               ...           ...           ...        ...
# 14395                           0.000             5             9        200
# 14396                           0.000             6             9        200
# 14397                           0.000             7             9        200
# 14398                           0.016             8             9        200
# 14399                           0.000             9             9        200
#
#        seed_lhs  dimension
# 0          1001         20
# 1          1001         20
# 2          1001         20
# 3          1001         20
# 4          1001         20
# ...         ...        ...
# 14395      1040         20
# 14396      1040         20
# 14397      1040         20
# 14398      1040         20
# 14399      1040         20
#
# [14400 rows x 74 columns]

# %%
complete_df
# Out:
#        ela_meta.lin_simple.adj_r2  ela_meta.lin_simple.intercept  \
# 0                        0.962144                     160.869757
# 1                        0.964638                     335.922967
# 2                        0.967974                     270.796736
# 3                        0.974033                     517.169845
# 4                        0.965981                     687.013063
# ...                           ...                            ...
# 14395                    0.144625                  370880.256463
# 14396                    0.120491                  386739.336532
# 14397                    0.104993                  391684.214659
# 14398                    0.075283                  381225.475439
# 14399                    0.084220                  379403.277033
#
#        ela_meta.lin_simple.coef.min  ela_meta.lin_simple.coef.max  \
# 0                          0.208150                      6.897319
# 1                          0.275050                      8.334917
# 2                          0.295733                      8.240517
# 3                          0.287559                      7.885662
# 4                          0.447831                      8.124321
# ...                             ...                           ...
# 14395                    739.974365                   8968.688930
# 14396                   1153.724119                   9984.493939
# 14397                    363.626773                   9695.349592
# 14398                     23.291751                  11076.243401
# 14399                    637.600190                   9666.423641
#
#        ela_meta.lin_simple.coef.max_by_min  ela_meta.lin_w_interact.adj_r2  \
# 0                                33.136309                             1.0
# 1                                30.303267                             1.0
# 2                                27.864715                             1.0
# 3                                27.422780                             1.0
# 4                                18.141469                             1.0
# ...                                    ...                             ...
# 14395                            12.120270                             1.0
# 14396                             8.654143                             1.0
# 14397                            26.662915                             1.0
# 14398                           475.543611                             1.0
# 14399                            15.160635                             1.0
#
#        ela_meta.quad_simple.adj_r2  ela_meta.quad_simple.cond  \
# 0                         1.000000                   1.000000
# 1                         1.000000                   1.000000
# 2                         1.000000                   1.000000
# 3                         1.000000                   1.000000
# 4                         1.000000                   1.000000
# ...                            ...                        ...
# 14395                     0.155769                   6.774635
# 14396                     0.210411                   3.884893
# 14397                     0.254936                   4.057301
# 14398                     0.340456                   3.501203
# 14399                     0.267714                   2.608607
#
#        ela_meta.quad_w_interact.adj_r2  ela_meta.costs_runtime  ...  \
# 0                                  1.0                   0.344  ...
# 1                                  1.0                   0.391  ...
# 2                                  1.0                   0.375  ...
# 3                                  1.0                   0.328  ...
# 4                                  1.0                   0.359  ...
# ...                                ...                     ...  ...
# 14395                              1.0                   0.265  ...
# 14396                              1.0                   0.312  ...
# 14397                              1.0                   0.265  ...
# 14398                              1.0                   0.282  ...
# 14399                              1.0                   0.282  ...
#
#        fitness_distance.distance_mean  fitness_distance.distance_std  \
# 0                           15.089905                       3.799821
# 1                           15.035332                       3.894132
# 2                           14.240422                       3.720427
# 3                           15.664009                       4.070778
# 4                           15.488229                       3.971765
# ...                               ...                            ...
# 14395                       17.547887                       4.579231
# 14396                       16.958328                       4.662510
# 14397                       17.437299                       4.526222
# 14398                       16.926827                       4.576537
# 14399                       16.552341                       4.194189
#
#        fitness_distance.fitness_mean  fitness_distance.fitness_std  \
# 0                          68.025586                     19.995332
# 1                         239.367762                     26.894356
# 2                         161.370658                     30.202780
# 3                         406.725583                     28.066969
# 4                         587.621887                     25.655925
# ...                              ...                           ...
# 14395                  199923.837446                  28547.814904
# 14396                  211203.126564                  24256.325677
# 14397                  218569.667090                  22860.200756
# 14398                  189939.097075                  38003.144007
# 14399                  198744.006092                  27034.532246
#
#        fitness_distance.costs_runtime  instance_idx  function_idx  n_samples  \
# 0                               0.000             0             1        200
# 1                               0.000             1             1        200
# 2                               0.000            10             1        200
# 3                               0.000            11             1        200
# 4                               0.000            12             1        200
# ...                               ...           ...           ...        ...
# 14395                           0.000             5             9        200
# 14396                           0.000             6             9        200
# 14397                           0.000             7             9        200
# 14398                           0.016             8             9        200
# 14399                           0.000             9             9        200
#
#        seed_lhs  dimension
# 0          1001         20
# 1          1001         20
# 2          1001         20
# 3          1001         20
# 4          1001         20
# ...         ...        ...
# 14395      1040         20
# 14396      1040         20
# 14397      1040         20
# 14398      1040         20
# 14399      1040         20
#
# [14400 rows x 74 columns]

# %%
FEATURE_DTYPES = {
    col: "float64"
    for col in pd.read_csv(
        reduced_files[0],
        nrows=0
    ).columns
}

META_DTYPES = {
    "dimension": "int16",
    "seed_lhs": "int32",
    "n_samples": "int32",
    "function_idx": "int16",
    "instance_idx": "int32",
    "reduction_ratio": "float32",
    "embedding_seed": "int32",
    "round": "int16",
}

# %%
# Generate DataFrames by loading CSV files and combining with metadata
reduced_dfs = []

for file_path in reduced_files:
    df = pd.read_csv(file_path)
    # Extract metadata for the current file
    meta = extract_meta_data_from_reduced_feature_file_path(file_path)
    # Add metadata as new columns to the DataFrame
    for key, value in meta.items():
        df[key] = value
    
    reduced_dfs.append(df)

reduced_df = (
    pd.concat(reduced_dfs, ignore_index=True)
    if reduced_dfs
    else pd.DataFrame()
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       2 reduced_dfs = []
#       4 for file_path in reduced_files:
# ----> 5     df = pd.read_csv(file_path)
#       6     # Extract metadata for the current file
#       7     meta = extract_meta_data_from_reduced_feature_file_path(file_path)
#
# File c:\ProgramData\miniconda3\envs\data_science\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\miniconda3\envs\data_science\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\ProgramData\miniconda3\envs\data_science\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\miniconda3\envs\data_science\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\ProgramData\miniconda3\envs\data_science\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:

# %%
len(reduced_files)
# Out:
# 990000

# %%
def load_reduced(fp):
    # Fast CSV read, no inference
    df = pd.read_csv(
        fp,
        dtype=FEATURE_DTYPES,
        low_memory=False,
        engine="c"
    )

    meta = extract_meta_data_from_reduced_feature_file_path(fp)

    # Typed metadata injection (no object columns)
    return df.assign(
        **{
            k: pd.Series(v, dtype=META_DTYPES[k], index=df.index)
            for k, v in meta.items()
        }
    )

# %%
# 3. Concatenate everything
reduced_df = pd.concat(
    map(load_reduced, reduced_files),
    ignore_index=True
)

# %%
# Store the final DataFrame
reduced_df.to_parquet("reduced_data_2.parquet", engine="pyarrow", compression="snappy")

# %%
complete_df.to_csv("complete_data_2.csv", index=False)

# %%
reduced_df.to_csv("reduced_data_2.csv", index=False)
