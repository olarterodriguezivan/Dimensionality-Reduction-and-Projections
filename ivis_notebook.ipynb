# %%
# Ivis uses several stochastic processes.
# To make sure that results are consistent from one run to another,
# we fix the random seed

import os
os.environ["PYTHONHASHSEED"]="1234"

import random
import numpy as np

import tensorflow as tf

np.random.seed(1234)
random.seed(1234)
tf.random.set_seed(1234)

# %%
from ivis import Ivis

# %%
from sklearn.datasets import fetch_rcv1
from sklearn.utils import resample

# %%
rcv1 = fetch_rcv1()
rcv1.data.shape
# Out:
# (804414, 47236)

# %%
N_SAMPLES = 10000 # number of subsamples. Increase or decrease depending on your hardware.

X, y = resample(rcv1.data, rcv1.target, replace=False,
                n_samples=N_SAMPLES, random_state=1234)

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 755294 stored elements and shape (10000, 47236)>

# %%
from sklearn.decomposition import TruncatedSVD

# %%
X = TruncatedSVD(n_components=150).fit_transform(X)

# %%
ivis = Ivis(model='maaten', n_epochs_without_progress=5)
ivis.fit(X)
# Out:
# Building KNN index
# 100%|██████████| 10000/10000 [00:00<00:00, 160481.79it/s]
# Extracting KNN neighbours
# 100%|██████████| 10000/10000 [00:00<00:00, 23085.85it/s]
# Training neural network
# Epoch 1/1000
# 79/79 [==============================] - 2s 14ms/step - loss: 1.6228
# Epoch 2/1000
# 79/79 [==============================] - 1s 14ms/step - loss: 1.2525
# Epoch 3/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 1.1036
# Epoch 4/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 1.0524
# Epoch 5/1000
# 79/79 [==============================] - 1s 16ms/step - loss: 1.0463
# Epoch 6/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 1.0456
# Epoch 7/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 1.0354
# Epoch 8/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 1.0335
# Epoch 9/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 1.0191
# Epoch 10/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 0.9810
# Epoch 11/1000
# 79/79 [==============================] - 1s 16ms/step - loss: 0.8509
# Epoch 12/1000
# 79/79 [==============================] - 1s 16ms/step - loss: 0.7404
# Epoch 13/1000
# 79/79 [==============================] - 1s 15ms/step - loss: 0.6799
# Epoch 14/1000
# 79/79 [==============================] - 1s 17ms/step - loss: 0.6465
# Epoch 15/1000
# 79/79 [==============================] - 1s 17ms/step - loss: 0.6095
# Epoch 16/1000
# 79/79 [==============================] - 1s 19ms/step - loss: 0.6038
# Epoch 17/1000
# 79/79 [==============================] - 1s 18ms/step - loss: 0.5720
# Epoch 18/1000
# 79/79 [==============================] - 2s 20ms/step - loss: 0.5591
# Epoch 19/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.5313
# Epoch 20/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.5181
# Epoch 21/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.4984
# Epoch 22/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.4670
# Epoch 23/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.4654
# Epoch 24/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.4241
# Epoch 25/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.4320
# Epoch 26/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.4213
# Epoch 27/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.4026
# Epoch 28/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.4030
# Epoch 29/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3811
# Epoch 30/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3937
# Epoch 31/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.3772
# Epoch 32/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.3662
# Epoch 33/1000
# 79/79 [==============================] - 2s 26ms/step - loss: 0.3637
# Epoch 34/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3719
# Epoch 35/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3517
# Epoch 36/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.3456
# Epoch 37/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3426
# Epoch 38/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.3326
# Epoch 39/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3298
# Epoch 40/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3456
# Epoch 41/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3212
# Epoch 42/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.3300
# Epoch 43/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3241
# Epoch 44/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3277
# Epoch 45/1000
# 79/79 [==============================] - 2s 25ms/step - loss: 0.3202
# Epoch 46/1000
# 79/79 [==============================] - 2s 24ms/step - loss: 0.3259
# Epoch 47/1000
# 79/79 [==============================] - 2s 26ms/step - loss: 0.3066
# Epoch 48/1000
# 79/79 [==============================] - 2s 29ms/step - loss: 0.3127
# Epoch 49/1000
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3123
# Epoch 50/1000
# 79/79 [==============================] - 2s 30ms/step - loss: 0.3134
# Epoch 51/1000
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3033
# Epoch 52/1000
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3020
# Epoch 53/1000
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2850
# Epoch 54/1000
# 79/79 [==============================] - 2s 27ms/step - loss: 0.2933
# Epoch 55/1000
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3170
# Epoch 56/1000
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2931
# Epoch 57/1000
# 79/79 [==============================] - 2s 27ms/step - loss: 0.3035
# Epoch 58/1000
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2986
# Ivis(model='maaten', n_epochs_without_progress=5)
