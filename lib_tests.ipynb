# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
from ioh import get_problem

# %%
prob = get_problem(fid=1, dimension=5, instance=1)

# %%
prob.bounds.lb
# Out:
# array([-5., -5., -5., -5., -5.])
